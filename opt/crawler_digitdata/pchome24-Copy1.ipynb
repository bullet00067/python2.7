# %%
import requests
res = []
res = requests.get("https://ecshweb.pchome.com.tw/search/v3.3/all/results?q=ssd&page=2&sort=sale/dc")

# %%
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '{"QTime":125,"totalRows":8836,"totalPage":100,"range":{"min":"","max":""},"cateName":"","q":"ssd","subq":"","token":["ssd"],"prods":[{"Id":"DRAH7A-A900959QT","cateId":"DRAH7O","picS":"\\/items\\/DRAH7AA900959QT\\/000002_1529570692.jpg","picB":"\\/items\\/DRAH7AA900959QT\\/000001_1542275049.jpg","name":"WD SSD 1TB M.2 SATA 3D NAND\\u56fa\\u614b\\u786c\\u789f(\\u85cd\\u6a19)","describe":"\\u9001\\u2605WD\\u96a8\\u8eab\\u4fdd\\u6eab\\u74f6WD \\u85cd\\u6a19 BLUE 1TB M.2 2280 3D NAND SATA SSD\\\\r\\\\n\\u8b80560m \\u5beb530m tlc \\u4e94\\u5e74\\u4fdd\\r\\n\\u25c6\\u9023\\u7e8c\\u8b80\\u53d6560mb s\\uff0c\\u9023\\u8b80\\u5beb\\u5165530mb s \\r\\n\\u25c6\\u7b26\\u5408m.2 sata\\u898f\\u683c (\\u9577\\u5ea680mm)\\r\\n\\u25c6\\u8017\\u96fb\\u91cf\\u964d\\u4f4e25%\\r\\n\\u25c6\\u9069\\u7528\\u65bc\\u8f15\\u8584\\u578b\\u96fb\\u8166\\u88dd\\u7f6e\\r\\n\\u25c6\\u767c\\u63ee\\u7cfb\\u7d71\\u6975\\u81f4\\u6548\\u80fd\\r\\n\\u25c6\\u8010\\u7528\\u6027\\u9ad8\\u9054400tbw\\r\\n\\u25c6\\u7d93\\u904ewd f.i.t. lab \\u9ad8\\u5ea6\\u76f8\\u5bb9\\u8a8d\\u8b49\\r\\n\\u25c6\\u5b98\\u7db2\\u514d\\u8cbb\\u4e0b\\u8f09 wd ssd \\u63a7\\u5236\\u9762\\u677f\\r\\n\\u25c6\\u4e94\\u5e74\\u6709\\u9650\\u4fdd\\u56fa\\r\\n\\r\\n\\r\\n\\r\\n\\u9928\\u9577\\u5c0f\\u53ee\\u5680\\uff1a\\u5132\\u503c\\u8cfc\\u8cb7\\u6700\\u5212\\u7b97\\uff5e\\r\\n\\u219111\\u6708\\u5132\\u503c\\u512a\\u60e0\\u6d3b\\u52d5\\uff0c\\u8acb\\u9ede\\u6211\\r\\n\\r\\n\\u2191\\u9280\\u884c\\u5237\\u5361\\u6d3b\\u52d5\\u8a73\\u60c5\\u8acb\\u9ede\\u5716\\u7247\\u4e86\\u89e3","price":4450,"originPrice":4450,"author":"","brand":"","publishDate":"","sellerId":"","isPChome":1,"isNC17":0,"couponActid":[],"BU":"ec"},{"Id":"DRAH6W-A900959QB","cateId":"DRAH7O","picS":"\\/items\\/DRAH6WA900959QB\\/000002_1529570805.jpg","picB":"\\/items\\/DRAH6WA900959QB\\/000001_1529570805.jpg","name":"WD SSD 250GB M.2 2280 NVMe PCIe Gen3 \\u56fa\\u614b\\u786c\\u789f(\\u9ed1\\u6a19)","describe":"\\u9001\\u2605WD\\u96a8\\u8eab\\u4fdd\\u6eab\\u74f6WD SSD 250GB M.2 2280 NVMe PCIe Gen3 \\u56fa\\u614b\\u786c\\u789f(\\u9ed1\\u6a19)\\\\r\\\\n\\u8b803000m \\u5beb1600m tlc \\u4e94\\u5e74\\u4fdd\\r\\n\\u25c6\\u9023\\u7e8c\\u8b80\\u53d63000mb s\\uff0c\\u9023\\u8b80\\u5beb\\u51651600mb s \\r\\n\\u25c6\\u7b26\\u5408m.2 sata\\u898f\\u683c (\\u9577\\u5ea680mm)\\r\\n\\u25c6\\u9069\\u7528\\u65bc\\u8f15\\u8584\\u578b\\u96fb\\u8166\\u88dd\\u7f6e\\r\\n\\u25c6\\u767c\\u63ee\\u7cfb\\u7d71\\u6975\\u81f4\\u6548\\u80fd\\r\\n\\u25c6\\u8010\\u7528\\u6027\\u9ad8\\u9054200tbw\\r\\n\\u25c6\\u7d93\\u904ewd f.i.t. lab \\u9ad8\\u5ea6\\u76f8\\u5bb9\\u8a8d\\u8b49\\r\\n\\u25c6\\u5b98\\u7db2\\u514d\\u8cbb\\u4e0b\\u8f09 wd ssd \\u63a7\\u5236\\u9762\\u677f\\r\\n\\u25c6\\u4e94\\u5e74\\u6709\\u9650\\u4fdd\\u56fa","price":2150,"originPrice":2150,"author":"","brand":"","publishDate":"","sellerId":"","isPChome":1,"isNC17":0,"couponActid":[],"BU":"ec"},{"Id":"DRAH6C-A9008F55S","cateId":"DRAH7O","picS":"\\/items\\/DRAH6CA9008F55S\\/000002_1506066449.jpg","picB":"\\/items\\/DRAH6CA9008F55S\\/000001_1506066449.jpg","name":"WD SSD 2TB M.2 SATA 3D NAND\\u56fa\\u614b\\u786c\\u789f(\\u85cd\\u6a19)","describe":"\\u9001\\u2605WD\\u96a8\\u8eab\\u4fdd\\u6eab\\u74f6WD SSD 2TB M.2 SATA 3D NAND\\u56fa\\u614b\\u786c\\u789f\\\\r\\\\n\\u8b80560m \\u5beb530m tlc \\u4e94\\u5e74\\u4fdd\\r\\n\\u25c6\\u9023\\u7e8c\\u8b80\\u53d6560mb s\\uff0c\\u9023\\u8b80\\u5beb\\u5165530mb s \\r\\n\\u25c6\\u7b26\\u5408m.2 sata\\u898f\\u683c (\\u9577\\u5ea680mm)\\r\\n\\u25c6\\u9069\\u7528\\u65bc\\u8f15\\u8584\\u578b\\u96fb\\u8166\\u88dd\\u7f6e\\r\\n\\u25c6\\u767c\\u63ee\\u7cfb\\u7d71\\u6975\\u81f4\\u6548\\u80fd\\r\\n\\u25c6\\u8010\\u7528\\u6027\\u9ad8\\u9054500tbw\\r\\n\\u25c6\\u7d93\\u904ewd f.i.t. lab \\u9ad8\\u5ea6\\u76f8\\u5bb9\\u8a8d\\u8b49\\r\\n\\u25c6\\u5b98\\u7db2\\u514d\\u8cbb\\u4e0b\\u8f09 wd ssd \\u63a7\\u5236\\u9762\\u677f\\r\\n\\u25c6\\u4e94\\u5e74\\u6709\\u9650\\u4fdd\\u56fa","price":9990,"originPrice":9990,"author":"","brand":"","publishDate":"","sellerId":"","isPChome":1,"isNC17":0,"cou ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.text, 'lxml')
soup
# Out:
# <html><body><p>{"QTime":125,"totalRows":8836,"totalPage":100,"range":{"min":"","max":""},"cateName":"","q":"ssd","subq":"","token":["ssd"],"prods":[{"Id":"DRAH7A-A900959QT","cateId":"DRAH7O","picS":"\/items\/DRAH7AA900959QT\/000002_1529570692.jpg","picB":"\/items\/DRAH7AA900959QT\/000001_1542275049.jpg","name":"WD SSD 1TB M.2 SATA 3D NAND\u56fa\u614b\u786c\u789f(\u85cd\u6a19)","describe":"\u9001\u2605WD\u96a8\u8eab\u4fdd\u6eab\u74f6WD \u85cd\u6a19 BLUE 1TB M.2 2280 3D NAND SATA SSD\\r\\n\u8b80560m \u5beb530m tlc \u4e94\u5e74\u4fdd\r\n\u25c6\u9023\u7e8c\u8b80\u53d6560mb s\uff0c\u9023\u8b80\u5beb\u5165530mb s \r\n\u25c6\u7b26\u5408m.2 sata\u898f\u683c (\u9577\u5ea680mm)\r\n\u25c6\u8017\u96fb\u91cf\u964d\u4f4e25%\r\n\u25c6\u9069\u7528\u65bc\u8f15\u8584\u578b\u96fb\u8166\u88dd\u7f6e\r\n\u25c6\u767c\u63ee\u7cfb\u7d71\u6975\u81f4\u6548\u80fd\r\n\u25c6\u8010\u7528\u6027\u9ad8\u9054400tbw\r\n\u25c6\u7d93\u904ewd f.i.t. lab \u9ad8\u5ea6\u76f8\u5bb9\u8a8d\u8b49\r\n\u25c6\u5b98\u7db2\u514d\u8cbb\u4e0b\u8f09 wd ssd \u63a7\u5236\u9762\u677f\r\n\u25c6\u4e94\u5e74\u6709\u9650\u4fdd\u56fa\r\n\r\n\r\n\r\n\u9928\u9577\u5c0f\u53ee\u5680\uff1a\u5132\u503c\u8cfc\u8cb7\u6700\u5212\u7b97\uff5e\r\n\u219111\u6708\u5132\u503c\u512a\u60e0\u6d3b\u52d5\uff0c\u8acb\u9ede\u6211\r\n\r\n\u2191\u9280\u884c\u5237\u5361\u6d3b\u52d5\u8a73\u60c5\u8acb\u9ede\u5716\u7247\u4e86\u89e3","price":4450,"originPrice":4450,"author":"","brand":"","publishDate":"","sellerId":"","isPChome":1,"isNC17":0,"couponActid":[],"BU":"ec"},{"Id":"DRAH6W-A900959QB","cateId":"DRAH7O","picS":"\/items\/DRAH6WA900959QB\/000002_1529570805.jpg","picB":"\/items\/DRAH6WA900959QB\/000001_1529570805.jpg","name":"WD SSD 250GB M.2 2280 NVMe PCIe Gen3 \u56fa\u614b\u786c\u789f(\u9ed1\u6a19)","describe":"\u9001\u2605WD\u96a8\u8eab\u4fdd\u6eab\u74f6WD SSD 250GB M.2 2280 NVMe PCIe Gen3 \u56fa\u614b\u786c\u789f(\u9ed1\u6a19)\\r\\n\u8b803000m \u5beb1600m tlc \u4e94\u5e74\u4fdd\r\n\u25c6\u9023\u7e8c\u8b80\u53d63000mb s\uff0c\u9023\u8b80\u5beb\u51651600mb s \r\n\u25c6\u7b26\u5408m.2 sata\u898f\u683c (\u9577\u5ea680mm)\r\n\u25c6\u9069\u7528\u65bc\u8f15\u8584\u578b\u96fb\u8166\u88dd\u7f6e\r\n\u25c6\u767c\u63ee\u7cfb\u7d71\u6975\u81f4\u6548\u80fd\r\n\u25c6\u8010\u7528\u6027\u9ad8\u9054200tbw\r\n\u25c6\u7d93\u904ewd f.i.t. lab \u9ad8\u5ea6\u76f8\u5bb9\u8a8d\u8b49\r\n\u25c6\u5b98\u7db2\u514d\u8cbb\u4e0b\u8f09 wd ssd \u63a7\u5236\u9762\u677f\r\n\u25c6\u4e94\u5e74\u6709\u9650\u4fdd\u56fa","price":2150,"originPrice":2150,"author":"","brand":"","publishDate":"","sellerId":"","isPChome":1,"isNC17":0,"couponActid":[],"BU":"ec"},{"Id":"DRAH6C-A9008F55S","cateId":"DRAH7O","picS":"\/items\/DRAH6CA9008F55S\/000002_1506066449.jpg","picB":"\/items\/DRAH6CA9008F55S\/000001_1506066449.jpg","name":"WD SSD 2TB M.2 SATA 3D NAND\u56fa\u614b\u786c\u789f(\u85cd\u6a19)","describe":"\u9001\u2605WD\u96a8\u8eab\u4fdd\u6eab\u74f6WD SSD 2TB M.2 SATA 3D NAND\u56fa\u614b\u786c\u789f\\r\\n\u8b80560m \u5beb530m tlc \u4e94\u5e74\u4fdd\r\n\u25c6\u9023\u7e8c\u8b80\u53d6560mb s\uff0c\u9023\u8b80\u5beb\u5165530mb s \r\n\u25c6\u7b26\u5408m.2 sata\u898f\u683c (\u9577\u5ea680mm)\r\n\u25c6\u9069\u7528\u65bc\u8f15\u8584\u578b\u96fb\u8166\u88dd\u7f6e\r\n\u25c6\u767c\u63ee\u7cfb\u7d71\u6975\u81f4\u6548\u80fd\r\n\u25c6\u8010\u7528\u6027\u9ad8\u9054500tbw\r\n\u25c6\u7d93\u904ewd f.i.t. lab \u9ad8\u5ea6\u76f8\u5bb9\u8a8d\u8b49\r\n\u25c6\u5b98\u7db2\u514d\u8cbb\u4e0b\u8f09 wd ssd \u63a7\u5236\u9762\u677f\r\n\u25c6\u4e94\u5e74\u6709\u9650\u4fdd\u56fa","price":9990,"originPrice":9990,"author":"","brand":"","publishDate":"","sellerId":"","isPChome":1,"isNC17":0,"couponActid":[],"BU":"ec"},{"Id":"DRAH6D-A9008L285","cateId":"DRAH7O","picS":"\/items\/DRAH6DA9008L285\/000002_1511950558.jpg","picB":"\/items\/DRAH6DA9008L285\/000001_1511950558.jpg","name":"WD SSD 120GB 2.5\u540b\u56fa\u614b\u786c\u789f(\u7da0\u6a19)","describe":"WD \u7da0\u6a19 Green 120GB 2.5\u540b SATAIII SSD\\r\\n\u8b80545m tlc \u4e09\u5e74\u4fdd\r\n\u25c6\u9023\u7e8c\u8b80\u53d6545mb s \r\n\u25c6 ...

# %%
import json
data = json.loads(res.text)
data.keys()
# Out:
# dict_keys(['QTime', 'totalRows', 'totalPage', 'range', 'cateName', 'q', 'subq', 'token', 'prods'])

# %%
data['prods']
# Out:
# [{'BU': 'ec',
#   'Id': 'DRAH7A-A900959QT',
#   'author': '',
#   'brand': '',
#   'cateId': 'DRAH7O',
#   'couponActid': [],
#   'describe': '送★WD隨身保溫瓶WD 藍標 BLUE 1TB M.2 2280 3D NAND SATA SSD\\r\\n讀560m 寫530m tlc 五年保\r\n◆連續讀取560mb s，連讀寫入530mb s \r\n◆符合m.2 sata規格 (長度80mm)\r\n◆耗電量降低25%\r\n◆適用於輕薄型電腦裝置\r\n◆發揮系統極致效能\r\n◆耐用性高達400tbw\r\n◆經過wd f.i.t. lab 高度相容認證\r\n◆官網免費下載 wd ssd 控制面板\r\n◆五年有限保固\r\n\r\n\r\n\r\n館長小叮嚀：儲值購買最划算～\r\n↑11月儲值優惠活動，請點我\r\n\r\n↑銀行刷卡活動詳情請點圖片了解',
#   'isNC17': 0,
#   'isPChome': 1,
#   'name': 'WD SSD 1TB M.2 SATA 3D NAND固態硬碟(藍標)',
#   'originPrice': 4450,
#   'picB': '/items/DRAH7AA900959QT/000001_1542275049.jpg',
#   'picS': '/items/DRAH7AA900959QT/000002_1529570692.jpg',
#   'price': 4450,
#   'publishDate': '',
#   'sellerId': ''},
#  {'BU': 'ec',
#   'Id': 'DRAH6W-A900959QB',
#   'author': '',
#   'brand': '',
#   'cateId': 'DRAH7O',
#   'couponActid': [],
#   'describe': '送★WD隨身保溫瓶WD SSD 250GB M.2 2280 NVMe PCIe Gen3 固態硬碟(黑標)\\r\\n讀3000m 寫1600m tlc 五年保\r\n◆連續讀取3000mb s，連讀寫入1600mb s \r\n◆符合m.2 sata規格 (長度80mm)\r\n◆適用於輕薄型電腦裝置\r\n◆發揮系統極致效能\r\n◆耐用性高達200tbw\r\n◆經過wd f.i.t. lab 高度相容認證\r\n◆官網免費下載 wd ssd 控制面板\r\n◆五年有限保固',
#   'isNC17': 0,
#   'isPChome': 1,
#   'name': 'WD SSD 250GB M.2 2280 NVMe PCIe Gen3 固態硬碟(黑標)',
#   'originPrice': 2150,
#   'picB': '/items/DRAH6WA900959QB/000001_1529570805.jpg',
#   'picS': '/items/DRAH6WA900959QB/000002_1529570805.jpg',
#   'price': 2150,
#   'publishDate': '',
#   'sellerId': ''},
#  {'BU': 'ec',
#   'Id': 'DRAH6C-A9008F55S',
#   'author': '',
#   'brand': '',
#   'cateId': 'DRAH7O',
#   'couponActid': [],
#   'describe': '送★WD隨身保溫瓶WD SSD 2TB M.2 SATA 3D NAND固態硬碟\\r\\n讀560m 寫530m tlc 五年保\r\n◆連續讀取560mb s，連讀寫入530mb s \r\n◆符合m.2 sata規格 (長度80mm)\r\n◆適用於輕薄型電腦裝置\r\n◆發揮系統極致效能\r\n◆耐用性高達500tbw\r\n◆經過wd f.i.t. lab 高度相容認證\r\n◆官網免費下載 wd ssd 控制面板\r\n◆五年有限保固',
#   'isNC17': 0,
#   'isPChome': 1,
#   'name': 'WD SSD 2TB M.2 SATA 3D NAND固態硬碟(藍標)',
#   'originPrice': 9990,
#   'picB': '/items/DRAH6CA9008F55S/000001_1506066449.jpg',
#   'picS': '/items/DRAH6CA9008F55S/000002_1506066449.jpg',
#   'price': 9990,
#   'publishDate': '',
#   'sellerId': ''},
#  {'BU': 'ec',
#   'Id': 'DRAH6D-A9008L285',
#   'author': '',
#   'brand': '',
#   'cateId': 'DRAH7O',
#   'couponActid': [],
#   'describe': 'WD 綠標 Green 120GB 2.5吋 SATAIII SSD\\r\\n讀545m tlc 三年保\r\n◆連續讀取545mb s \r\n◆提升電腦日常運算效能\r\n◆耐用性40tbw\r\n◆經過wd f.i.t. lab 高度相容認證\r\n◆官網免費下載 wd ssd 控制面板\r\n◆三年有限保固',
#   'isNC17': 0,
#   'isPChome': 1,
#   'name': 'WD SSD 120GB 2.5吋固態硬碟(綠標)',
#   'originPrice': 740,
#   'picB': '/items/DRAH6DA9008L285/000001_1511950558.jpg',
#   'picS': '/items/DRAH6DA9008L285/000002_1511950558.jpg',
#   'price': 740,
#   'publishDate': '',
#   'sellerId': ''},
#  {'BU': 'ec',
#   'Id': 'DRAH6C-A9008F55Q',
#   'author': '',
#   'brand': '',
#   'cateId': 'DRAH7O',
#   'couponActid': [],
#   'describe': '送★WD隨身保溫瓶WD SSD 250GB M.2 SATA 3D NAND固態硬碟\\r\\n讀550m 寫525m tlc 五年保\r\n◆連續讀取550mb s，連讀寫入525mb s \r\n◆符合m.2 sata規格 (長度80mm)\r\n◆適用於輕薄型電腦裝置\r\n◆發揮系統極致效能\r\n◆耐用性高達100tbw\r\n◆經過wd f.i.t. lab 高度相容認證\r\n◆官網免費下載 wd ssd 控制面板\r\n◆五年有限保固',
#   'isNC17': 0,
#   'isPChome': 1,
#   'name': 'WD SSD 250GB M.2 SATA 3D NAND固態硬碟(藍標)',
#   'originPrice': 1490,
#   'picB': '/items/DRAH6CA9008F55Q/000001_1506066487.jpg',
#   'picS': '/items/DRAH6CA9008F55Q/000002_1506066487.jpg',
#   'price': 1490,
#   'publishDate': '',
#   'sellerId': ''},
#  {'BU': 'ec',
#   'Id': 'DRAH6D-A9008Y92B',
#   'author': '',
#   'brand': '',
#   'cateId': 'DRAH7O',
#   'couponActid': [],
#   'describe': '送★WD隨身保溫瓶WD 綠標 SSD 240GB M.2 2280 SATA 固態硬碟\\r\\n讀545m tlc 三年保\r\n◆連續讀取545mb s\r\n◆符合m.2 sata規格 (長度80mm)\r\n◆適用於輕薄型電腦裝置\r\n◆發揮系統極致效能\r\n◆經過wd f.i.t. lab 高度相容認證\r\n◆官網免費下載 wd ssd 控制面板\r\n◆三年有限保固',
#   'isNC17': 0,
#   'isPChome': 1,
#   'name': 'WD SSD 240GB M.2 2280 SATA 固態硬碟(綠標)',
#   'originPrice': 1190,
#   'picB': '/items/DRAH6DA9008Y92B/000001_1526610281.jpg',
#   'picS': '/items/DRAH6DA9008Y92B/000002_1526610281.jpg',
#   'price': 1190,
#   'publishDate': '',
#   'sellerId': ''},
#  {'BU': 'ec',
#   'Id': 'DRAH2M-A90099SG2',
#   'author': '',
#   'brand': '',
#   'cateId': 'DRAH2M',
#   'couponActid': [],
#   'describe': 'Seagate Fast SSD 500GB 外接式固態硬碟\\r\\n讀540m 寫500m tlc 三年保\r\n★連續速度讀:540mb s 寫:500mb s \r\n★極至輕巧、時尚、高質感、便利好攜\r\n★提供兩個月adobe creative cloud photography計劃會員資格\r\n★附備份與資料夾鏡射軟體 輕鬆監控目標資料夾\r\n★隨附type-c轉type-a連接線\r\n★保固內可享免費資料救援一次 \r\n★三年保固',
#   'isNC17': 0,
#   'isPChome': 1,
#   'name': 'Seagate Fast SSD 500GB 外接式固態硬碟',
#   'originPrice': 4688,
#   'picB': '/items/DRAH2MA90099SG2/000001_1545186256.jpg',
#   'picS': '/items/DRAH2MA90099SG2/000002_1533794822.jpg',
#   'price': 4688,
#   'publishDate': '',
#   'sellerId': ''},
#  {'BU': 'ec',
#   'Id': 'DRAH5Z-A9009HQID',
#   'author': '',
#   'brand': '',
#   'cateId': 'DRAH5Z',
#   'couponActid': [],
#   'describe': '技嘉 GIGABYTE 512GB 2.5吋 SATAIII SSD\\r\\n規格尺寸: 2.5吋，內接式固態硬碟(ssd)\r\n傳輸介面: sata 6.0gb s\r\n容量: 512gb\r\n保固: 5年保固\r\n連續讀取速度: 最高達530 mb s\r\n連續寫入速度: 最高達500 mb s\r\n採用高品質toshiba 3d tlc nand 快閃記憶體\r\n內建ddr3l 記憶體快取，滿足高速運轉讀取需求\r\n支援trim 指令及 s.m.a.r.t 自我檢測分析報告技術',
#   'isNC17': 0,
#   'isPChome': 1,
#   'name': '技嘉 GIGABYTE 512GB 2.5吋 SATAIII SSD',
#   'originPrice': 2188,
#   'picB': '/items/DRAH5ZA9009HQID/000001_1540280667.jpg',
#   'picS': '/items/DRAH5ZA9009HQID/000002_1540280667.jpg',
#   'price': 2188,
#   'publishDate': '',
#   'sellerId': ''},
#  {'BU': 'ec',
#   'Id': 'DRAH2M-A90099SG6',
#   'author': '',
#   'brand': '',
#   'cateId': 'DRAH2M',
#   'couponActid': [],
#   'describe': 'Seagate Fast SSD 1TB 外接式固態硬碟\\r\\n讀540m 寫500m tlc 三年保\r\n★連續速度讀:540mb s 寫:500mb s \r\n★極至輕巧、時尚、高質感、便利好攜\r\n★提供兩個月adobe creative cloud photography計劃會員資格\r\n★附備份與資料夾鏡射軟體 輕鬆監控目標資料夾\r\n★隨附type-c轉type-a連接線\r\n★保固內可享免費資料救援一次 \r\n★三年保固\r\n\r\n\r\n館長小叮嚀：儲值購買最划算～\r\n↑11月儲值優惠活動，請點我\r\n\r\n↑銀行刷卡活動詳情請點圖片了解',
#   'isNC17': 0,
#   'isPChome': 1,
#   'name': 'Seagate Fast SSD 1TB 外接式固態硬碟',
#   'originPrice': 9688,
#   'picB': '/items/DRAH2MA90099SG6/000001_1533794626.jpg',
#   'picS': '/items/DRAH2MA90099SG6/000002_1533794626.jpg',
#   'price': 9688,
#   'publishDate': '',
#   'sellerId': ''},
#  {'BU': 'ec',
#   'Id': 'DRAH5Z-A9009HQHG',
#   'author': '',
#   'brand': '',
#   'cateId': 'DRAH5Z',
#   'couponActid': [],
#   'describe': '技嘉 GIGABYTE 240GB 2.5吋 SATAIII SSD\\r\\n規格尺寸: 2.5吋，內接式固態硬碟(ssd)\r\n傳輸介面: sata 6.0gb s\r\n容量: 240gb*\r\n保固: 3年保固1年換新*\r\n連續讀取速度: 最高達500 mb s**\r\n連續寫入速度: 最高達420 mb s**\r\n支援trim 指令及 s.m.a.r.t 自我檢測分析報告技術',
#   'isNC17': 0,
#   'isPChome': 1,
#   'name': '技嘉 GIGABYTE 240GB 2.5吋 SATAIII SSD',
#   'originPrice': 1168,
#   'picB': '/items/DRAH5ZA9009HQHG/000001_1540280160.jpg',
#   'picS': '/items/DRAH5ZA9009HQHG/000002_1540280160.jpg',
#   'price': 1168,
#   'publishDate': '',
#   'sellerId': ''},
#  {'BU': 'ec',
#   'Id': 'DRAH6D-A9008Z9AV',
#   'author': '',
#   'brand': '',
#   'cateId': 'DRAH7O',
#   'couponActid': [],
#   'describe': '送★WD隨身保溫瓶WD 綠標 SSD 240GB M.2 2280 SATA 固態硬碟\\r\\n讀545m tlc 三年保\r\n◆連續讀取540mb s\r\n◆符合m.2 sata規格 (長度80mm)\r\n◆適用於輕薄型電腦裝置\r\n◆發揮系統極致效能\r\n◆經過wd f.i.t. lab 高度相容認證\r\n◆官網免費下載 wd ssd 控制面板\r\n◆三年有限保固',
#   'isNC17': 0,
#   'isPChome': 1,
#   'name': 'WD SSD 240GB M.2 2280 SATA 固態硬碟(綠標)',
#   'originPrice': 1190,
#   'picB': '/items/DRAH6DA9008Z9AV/000001_1525073500.jpg',
#   'picS': '/items/DRAH6DA9008Z9AV/000002_1525073500.jpg',
#   'price': 1190,
#   'publishDate': '',
#   'sellerId': ''},
#  {'BU': 'ec',
#   'Id': 'DRAH7O-A9009ETJW',
#   'author': '',
#   'brand': '',
#   'cateId': 'DRAH7O',
#   'couponActid': [],
#   'describe': '送★WD隨身保溫瓶WD SSD 480GB M.2 2280 SATA 固態硬碟(綠標)\\r\\n讀545m tlc 三年保\r\n◆連續讀取545mb s\r\n◆符合m.2 sata規格 (長度80mm)\r\n◆適用於輕薄型電腦裝置\r\n◆發揮系統極致效能\r\n◆經過wd f.i.t. lab 高度相容認證\r\n◆官網免費下載 wd ssd 控制面板\r\n◆三年有限保固',
#   'isNC17': 0,
#   'isPChome': 1,
#   'name': 'WD SSD 480GB M.2 2280 SATA 固態硬碟(綠標)',
#   'originPrice': 1990,
#   'picB': '/items/DRAH7OA9009ETJW/000001_1536899026.jpg',
#   'picS': '/items/DRAH7OA9009ETJW/000002_1536899026.jpg',
#   'price': 1990,
#   'publishDate': '',
#   'sellerId': ''},
#  {'BU': 'ec',
#   'Id': 'DRAH5Z-A9009HQHM',
#   'author': '',
#   'brand': '',
#   'cateId': 'DRAH5Z',
#   'couponActid': [],
#   'describe': '技嘉 GIGABYTE 128GB M.2 2280 PCIe SSD\\r\\n規格尺寸: m.2 2280，內接式固態硬碟(ssd)\r\n傳輸介面: pci-express 3.0 x2  nvme 1.3\r\n容量: 128gb*\r\n保固: 3年保固\r\n連續讀取速度:最高達1100 mb s**\r\n連續寫入速度:最高達500 mb s**\r\n支援主機記憶體緩衝技術  hmb (host memory buffer)\r\n支援trim 指令及 s.m.a.r.t 自我檢測分析報告技術',
#   'isNC17': 0,
#   'isPChome': 1,
#   'name': '技嘉 GIGABYTE 128GB M.2 2280 PCIe SSD',
#   'originPrice': 1190,
#   'picB': '/items/DRAH5ZA9009HQHM/000001_1540279601.jpg',
#   'picS': '/items/DRAH5ZA9009HQHM/000002_1540279601.jpg',
#   'price': 1190,
#   'publishDate': '',
#   'sellerId': ''},
#  {'BU': 'ec',
#   'Id': 'DRAH6C-A90095MUT',
#   'author': '',
#   'brand': '',
#   'cateId': 'DRAH7O',
#   'couponActid': [],
#   'describe': '送★WD隨身保溫瓶WD SSD 2TB M.2 SATA 3D NAND固態硬碟\\r\\n讀560m 寫530m tlc 五年保\r\n◆連續讀取560mb s，連讀寫入530mb s \r\n◆符合m.2 sata規格 (長度80mm)\r\n◆適用於輕薄型電腦裝置\r\n◆發揮系統極致效能\r\n◆耐用性高達500tbw\r\n◆經過wd f.i.t. lab 高度相容認證\r\n◆官網免費下載 wd ssd 控制面板\r\n◆五年有限保固\r\n\r\n\r\n\r\n\r\n館長小叮嚀：儲值購買最划算～\r\n↑11月儲值優惠活動，請點我\r\n\r\n↑銀行刷卡活動詳情請點圖片了解',
#   'isNC17': 0,
#   'isPChome': 1,
#   'name': 'WD SSD 2TB M.2 SATA 3D NAND固態硬碟(藍標)',
#   'originPrice': 9990,
#   'picB': '/items/DRAH6CA90095MUT/000001_1529917160.jpg',
#   'picS': '/items/DRAH6CA90095MUT/000002_1529917160.jpg',
#   'price': 9990,
#   'publishDate': '',
#   'sellerId': ''},
#  {'BU': 'ec',
#   'Id': 'DRAH2M-A90099SJB',
#   'author': '',
#   'brand': '',
#   'cateId': 'DRAH2M',
#   'couponActid': [],
#   'describe': 'Seagate Fast SSD 2TB 外接式固態硬碟\\r\\n讀540m 寫500m tlc 三年保\r\n★連續速度讀:540mb s 寫:500mb s \r\n★極至輕巧、時尚、高質感、便利好攜\r\n★提供兩個月adobe creative cloud photography計劃會員資格\r\n★附備份與資料夾鏡射軟體 輕鬆監控目標資料夾\r\n★隨附type-c轉type-a連接線\r\n★保固內可享免費資料救援一次 \r\n★三年保固\r\n\r\n\r\n\r\n館長小叮嚀：儲值購買最划算～\r\n↑11月儲值優惠活動，請點我\r\n\r\n↑銀行刷卡活動詳情請點圖片了解',
#   'isNC17': 0,
#   'isPChome': 1,
#   'name': 'Seagate Fast SSD 2TB 外接式固態硬碟',
#   'originPrice': 19999,
#   'picB': '/items/DRAH2MA90099SJB/000001_1533794373.jpg',
#   'picS': '/items/DRAH2MA90099SJB/000002_1533794373.jpg',
#   'price': 19999,
#   'publishDate': '',
#   'sellerId': ''},
#  {'BU': 'ec',
#   'Id': 'DRAH2M-A90099SI4',
#   'author': '',
#   'brand': '',
#   'cateId': 'DRAH2M',
#   'couponActid': [],
#   'describe': 'Seagate Fast SSD 250GB 外接式固態硬碟\\r\\n讀540m 寫500m tlc 三年保\r\n★連續速度讀:540mb s 寫:500mb s \r\n★極至輕巧、時尚、高質感、便利好攜\r\n★提供兩個月adobe creative cloud photography計劃會員資格\r\n★附備份與資料夾鏡射軟體 輕鬆監控目標資料夾\r\n★隨附type-c轉type-a連接線\r\n★保固內可享免費資料救援一次 \r\n★三年保固',
#   'isNC17': 0,
#   'isPChome': 1,
#   'name': 'Seagate Fast SSD 250GB 外接式固態硬碟',
#   'originPrice': 2999,
#   'picB': '/items/DRAH2MA90099SI4/000001_1533794465.jpg',
#   'picS': '/items/DRAH2MA90099SI4/000002_1533794465.jpg',
#   'price': 2999,
#   'publishDate': '',
#   'sellerId': ''},
#  {'BU': 'ec',
#   'Id': 'DRAH6D-A9008Z9AU',
#   'author': '',
#   'brand': '',
#   'cateId': 'DRAH7O',
#   'couponActid': [],
#   'describe': '送★WD隨身保溫瓶WD 綠標 SSD 240GB 2.5吋固態硬碟\\r\\n讀545m tlc 三年保\r\n◆連續讀取545mb s \r\n◆提升電腦日常運算效能\r\n◆耐用性40tbw\r\n◆經過wd f.i.t. lab 高度相容認證\r\n◆官網免費下載 wd ssd 控制面板\r\n◆三年有限保固\r\n本商品為特賣商品，恕不送贈品！',
#   'isNC17': 0,
#   'isPChome': 1,
#   'name': 'WD SSD 240GB 2.5吋固態硬碟(綠標)',
#   'originPrice': 1190,
#   'picB': '/items/DRAH6DA9008Z9AU/000001_1529569395.jpg',
#   'picS': '/items/DRAH6DA9008Z9AU/000002_1524799131.jpg',
#   'price': 1190,
#   'publishDate': '',
#   'sellerId': ''},
#  {'BU': 'ec',
#   'Id': 'DRAH7O-A9009QY65',
#   'author': '',
#   'brand': '',
#   'cateId': 'DRAH7O',
#   'couponActid': [],
#   'describe': 'WD SSD 480GB 2.5吋固態硬碟(綠標)\\r\\n讀545m tlc 三年保\r\n◆連續讀取545mb s \r\n◆提升電腦日常運算效能\r\n◆耐用性40tbw\r\n◆經過wd f.i.t. lab 高度相容認證\r\n◆官網免費下載 wd ssd 控制面板\r\n◆三年有限保固',
#   'isNC17': 0,
#   'isPChome': 1,
#   'name': 'WD SSD 480GB 2.5吋固態硬碟(綠標)',
#   'originPrice': 1990,
#   'picB': '/items/DRAH7OA9009QY65/000001_1547863917.jpg',
#   'picS': '/items/DRAH7OA9009QY65/000002_1547863917.jpg',
#   'price': 1990,
#   'publishDate': '',
#   'sellerId': ''},
#  {'BU': 'ec',
#   'Id': 'DRAH7A-A900959MC',
#   'author': '',
#   'brand': '',
#   'cateId': 'DRAH7O',
#   'couponActid': [],
#   'describe': '送★WD隨身保溫瓶WD SSD 250GB 2.5吋 3D NAND 固態硬碟\\r\\n讀550m 寫525m tlc 五年保\r\n◆連續讀取550mb s，連讀寫入525mb s \r\n◆發揮系統極致效能\r\n◆耐用性高達100tbw\r\n◆經過wd f.i.t. lab 高度相容認證\r\n◆官網免費下載 wd ssd 控制面板\r\n◆五年有限保固',
#   'isNC17': 0,
#   'isPChome': 1,
#   'name': 'WD SSD 250GB 2.5吋 3D NAND 固態硬碟(藍標)',
#   'originPrice': 1490,
#   'picB': '/items/DRAH7AA900959MC/000001_1529570114.jpg',
#   'picS': '/items/DRAH7AA900959MC/000002_1529570114.jpg',
#   'price': 1490,
#   'publishDate': '',
#   'sellerId': ''},
#  {'BU': 'ec',
#   'Id': 'DRAH6D-A9008S1RI',
#   'author': '',
#   'brand': '',
#   'cateId': 'DRAH7O',
#   'couponActid': [],
#   'describe': 'WD 綠標 SSD 120GB M.2 2280 SATA 固態硬碟\\r\\n讀545m tlc 三年保\r\n◆連續讀取545mb s\r\n◆符合m.2 sata規格 (長度80mm)\r\n◆適用於輕薄型電腦裝置\r\n◆發揮系統極致效能\r\n◆經過wd f.i.t. lab 高度相容認證\r\n◆官網免費下載 wd ssd 控制面板\r\n◆三年有限保固',
#   'isNC17': 0,
#   'isPChome': 1,
#   'name': 'WD SSD 120GB M.2 2280 SATA 固態硬碟(綠標)',
#   'originPrice': 740,
#   'picB': '/items/DRAH6DA9008S1RI/000001_1518146062.jpg',
#   'picS': '/items/DRAH6DA9008S1RI/000002_1518146062.jpg',
#   'price': 740,
#   'publishDate': '',
#   'sellerId': ''}]

# %%
import pandas
products = []
df = pandas.DataFrame(data['prods'])
products.append(df)
products_all = pandas.concat(products)

# %%
products_all
# Out:
#     BU                Id author brand  cateId couponActid  \
# 0   ec  DRAH7A-A900959QT               DRAH7O          []
# 1   ec  DRAH6W-A900959QB               DRAH7O          []
# 2   ec  DRAH6C-A9008F55S               DRAH7O          []
# 3   ec  DRAH6D-A9008L285               DRAH7O          []
# 4   ec  DRAH6C-A9008F55Q               DRAH7O          []
# 5   ec  DRAH6D-A9008Y92B               DRAH7O          []
# 6   ec  DRAH2M-A90099SG2               DRAH2M          []
# 7   ec  DRAH5Z-A9009HQID               DRAH5Z          []
# 8   ec  DRAH2M-A90099SG6               DRAH2M          []
# 9   ec  DRAH5Z-A9009HQHG               DRAH5Z          []
# 10  ec  DRAH6D-A9008Z9AV               DRAH7O          []
# 11  ec  DRAH7O-A9009ETJW               DRAH7O          []
# 12  ec  DRAH5Z-A9009HQHM               DRAH5Z          []
# 13  ec  DRAH6C-A90095MUT               DRAH7O          []
# 14  ec  DRAH2M-A90099SJB               DRAH2M          []
# 15  ec  DRAH2M-A90099SI4               DRAH2M          []
# 16  ec  DRAH6D-A9008Z9AU               DRAH7O          []
# 17  ec  DRAH7O-A9009QY65               DRAH7O          []
# 18  ec  DRAH7A-A900959MC               DRAH7O          []
# 19  ec  DRAH6D-A9008S1RI               DRAH7O          []
#
#                                              describe  isNC17  isPChome  \
# 0   送★WD隨身保溫瓶WD 藍標 BLUE 1TB M.2 2280 3D NAND SATA ...       0         1
# 1   送★WD隨身保溫瓶WD SSD 250GB M.2 2280 NVMe PCIe Gen3 ...       0         1
# 2   送★WD隨身保溫瓶WD SSD 2TB M.2 SATA 3D NAND固態硬碟\r\n讀5...       0         1
# 3   WD 綠標 Green 120GB 2.5吋 SATAIII SSD\r\n讀545m tl...       0         1
# 4   送★WD隨身保溫瓶WD SSD 250GB M.2 SATA 3D NAND固態硬碟\r\n...       0         1
# 5   送★WD隨身保溫瓶WD 綠標 SSD 240GB M.2 2280 SATA 固態硬碟\r\...       0         1
# 6   Seagate Fast SSD 500GB 外接式固態硬碟\r\n讀540m 寫500m ...       0         1
# 7   技嘉 GIGABYTE 512GB 2.5吋 SATAIII SSD\r\n規格尺寸: 2....       0         1
# 8   Seagate Fast SSD 1TB 外接式固態硬碟\r\n讀540m 寫500m tl...       0         1
# 9   技嘉 GIGABYTE 240GB 2.5吋 SATAIII SSD\r\n規格尺寸: 2....       0         1
# 10  送★WD隨身保溫瓶WD 綠標 SSD 240GB M.2 2280 SATA 固態硬碟\r\...       0         1
# 11  送★WD隨身保溫瓶WD SSD 480GB M.2 2280 SATA 固態硬碟(綠標)\r...       0         1
# 12  技嘉 GIGABYTE 128GB M.2 2280 PCIe SSD\r\n規格尺寸: m...       0         1
# 13  送★WD隨身保溫瓶WD SSD 2TB M.2 SATA 3D NAND固態硬碟\r\n讀5...       0         1
# 14  Seagate Fast SSD 2TB 外接式固態硬碟\r\n讀540m 寫500m tl...       0         1
# 15  Seagate Fast SSD 250GB 外接式固態硬碟\r\n讀540m 寫500m ...       0         1
# 16  送★WD隨身保溫瓶WD 綠標 SSD 240GB 2.5吋固態硬碟\r\n讀545m tlc...       0         1
# 17  WD SSD 480GB 2.5吋固態硬碟(綠標)\r\n讀545m tlc 三年保\r\n...       0         1
# 18  送★WD隨身保溫瓶WD SSD 250GB 2.5吋 3D NAND 固態硬碟\r\n讀55...       0         1
# 19  WD 綠標 SSD 120GB M.2 2280 SATA 固態硬碟\r\n讀545m tl...       0         1
#
#                                              name  originPrice  \
# 0             WD SSD 1TB M.2 SATA 3D NAND固態硬碟(藍標)         4450
# 1   WD SSD 250GB M.2 2280 NVMe PCIe Gen3 固態硬碟(黑標)         2150
# 2             WD SSD 2TB M.2 SATA 3D NAND固態硬碟(藍標)         9990
# 3                       WD SSD 120GB 2.5吋固態硬碟(綠標)          740
# 4           WD SSD 250GB M.2 SATA 3D NAND固態硬碟(藍標)         1490
# 5             WD SSD 240GB M.2 2280 SATA 固態硬碟(綠標)         1190
# 6                  Seagate Fast SSD 500GB 外接式固態硬碟         4688
# 7              技嘉 GIGABYTE 512GB 2.5吋 SATAIII SSD         2188
# 8                    Seagate Fast SSD 1TB 外接式固態硬碟         9688
# 9              技嘉 GIGABYTE 240GB 2.5吋 SATAIII SSD         1168
# 10            WD SSD 240GB M.2 2280 SATA 固態硬碟(綠標)         1190
# 11            WD SSD 480GB M.2 2280 SATA 固態硬碟(綠標)         1990
# 12            技嘉 GIGABYTE 128GB M.2 2280 PCIe SSD         1190
# 13            WD SSD 2TB M.2 SATA 3D NAND固態硬碟(藍標)         9990
# 14                   Seagate Fast SSD 2TB 外接式固態硬碟        19999
# 15                 Seagate Fast SSD 250GB 外接式固態硬碟         2999
# 16                      WD SSD 240GB 2.5吋固態硬碟(綠標)         1190
# 17                      WD SSD 480GB 2.5吋固態硬碟(綠標)         1990
# 18             WD SSD 250GB 2.5吋 3D NAND 固態硬碟(藍標)         1490
# 19            WD SSD 120GB M.2 2280 SATA 固態硬碟(綠標)          740
#
#                                             picB  \
# 0   /items/DRAH7AA900959QT/000001_1542275049.jpg
# 1   /items/DRAH6WA900959QB/000001_1529570805.jpg
# 2   /items/DRAH6CA9008F55S/000001_1506066449.jpg
# 3   /items/DRAH6DA9008L285/000001_1511950558.jpg
# 4   /items/DRAH6CA9008F55Q/000001_1506066487.jpg
# 5   /items/DRAH6DA9008Y92B/000001_1526610281.jpg
# 6   /items/DRAH2MA90099SG2/000001_1545186256.jpg
# 7   /items/DRAH5ZA9009HQID/000001_1540280667.jpg
# 8   /items/DRAH2MA90099SG6/000001_1533794626.jpg
# 9   /items/DRAH5ZA9009HQHG/000001_1540280160.jpg
# 10  /items/DRAH6DA9008Z9AV/000001_1525073500.jpg
# 11  /items/DRAH7OA9009ETJW/000001_1536899026.jpg
# 12  /items/DRAH5ZA9009HQHM/000001_1540279601.jpg
# 13  /items/DRAH6CA90095MUT/000001_1529917160.jpg
# 14  /items/DRAH2MA90099SJB/000001_1533794373.jpg
# 15  /items/DRAH2MA90099SI4/000001_1533794465.jpg
# 16  /items/DRAH6DA9008Z9AU/000001_1529569395.jpg
# 17  /items/DRAH7OA9009QY65/000001_1547863917.jpg
# 18  /items/DRAH7AA900959MC/000001_1529570114.jpg
# 19  /items/DRAH6DA9008S1RI/000001_1518146062.jpg
#
#                                             picS  price publishDate sellerId
# 0   /items/DRAH7AA900959QT/000002_1529570692.jpg   4450
# 1   /items/DRAH6WA900959QB/000002_1529570805.jpg   2150
# 2   /items/DRAH6CA9008F55S/000002_1506066449.jpg   9990
# 3   /items/DRAH6DA9008L285/000002_1511950558.jpg    740
# 4   /items/DRAH6CA9008F55Q/000002_1506066487.jpg   1490
# 5   /items/DRAH6DA9008Y92B/000002_1526610281.jpg   1190
# 6   /items/DRAH2MA90099SG2/000002_1533794822.jpg   4688
# 7   /items/DRAH5ZA9009HQID/000002_1540280667.jpg   2188
# 8   /items/DRAH2MA90099SG6/000002_1533794626.jpg   9688
# 9   /items/DRAH5ZA9009HQHG/000002_1540280160.jpg   1168
# 10  /items/DRAH6DA9008Z9AV/000002_1525073500.jpg   1190
# 11  /items/DRAH7OA9009ETJW/000002_1536899026.jpg   1990
# 12  /items/DRAH5ZA9009HQHM/000002_1540279601.jpg   1190
# 13  /items/DRAH6CA90095MUT/000002_1529917160.jpg   9990
# 14  /items/DRAH2MA90099SJB/000002_1533794373.jpg  19999
# 15  /items/DRAH2MA90099SI4/000002_1533794465.jpg   2999
# 16  /items/DRAH6DA9008Z9AU/000002_1524799131.jpg   1190
# 17  /items/DRAH7OA9009QY65/000002_1547863917.jpg   1990
# 18  /items/DRAH7AA900959MC/000002_1529570114.jpg   1490
# 19  /items/DRAH6DA9008S1RI/000002_1518146062.jpg    740

# %%
products_all.columns
products_all['dexcribe'] = products_all['describe'].str.strip()

# %%
products_all.loc[products_all['name'].notnull(), ['name','originPrice','price','describe']]
# Out:
#                                              name  originPrice  price  \
# 0             WD SSD 1TB M.2 SATA 3D NAND固態硬碟(藍標)         4450   4450
# 1   WD SSD 250GB M.2 2280 NVMe PCIe Gen3 固態硬碟(黑標)         2150   2150
# 2             WD SSD 2TB M.2 SATA 3D NAND固態硬碟(藍標)         9990   9990
# 3                       WD SSD 120GB 2.5吋固態硬碟(綠標)          740    740
# 4           WD SSD 250GB M.2 SATA 3D NAND固態硬碟(藍標)         1490   1490
# 5             WD SSD 240GB M.2 2280 SATA 固態硬碟(綠標)         1190   1190
# 6                  Seagate Fast SSD 500GB 外接式固態硬碟         4688   4688
# 7              技嘉 GIGABYTE 512GB 2.5吋 SATAIII SSD         2188   2188
# 8                    Seagate Fast SSD 1TB 外接式固態硬碟         9688   9688
# 9              技嘉 GIGABYTE 240GB 2.5吋 SATAIII SSD         1168   1168
# 10            WD SSD 240GB M.2 2280 SATA 固態硬碟(綠標)         1190   1190
# 11            WD SSD 480GB M.2 2280 SATA 固態硬碟(綠標)         1990   1990
# 12            技嘉 GIGABYTE 128GB M.2 2280 PCIe SSD         1190   1190
# 13            WD SSD 2TB M.2 SATA 3D NAND固態硬碟(藍標)         9990   9990
# 14                   Seagate Fast SSD 2TB 外接式固態硬碟        19999  19999
# 15                 Seagate Fast SSD 250GB 外接式固態硬碟         2999   2999
# 16                      WD SSD 240GB 2.5吋固態硬碟(綠標)         1190   1190
# 17                      WD SSD 480GB 2.5吋固態硬碟(綠標)         1990   1990
# 18             WD SSD 250GB 2.5吋 3D NAND 固態硬碟(藍標)         1490   1490
# 19            WD SSD 120GB M.2 2280 SATA 固態硬碟(綠標)          740    740
#
#                                              describe
# 0   送★WD隨身保溫瓶WD 藍標 BLUE 1TB M.2 2280 3D NAND SATA ...
# 1   送★WD隨身保溫瓶WD SSD 250GB M.2 2280 NVMe PCIe Gen3 ...
# 2   送★WD隨身保溫瓶WD SSD 2TB M.2 SATA 3D NAND固態硬碟\r\n讀5...
# 3   WD 綠標 Green 120GB 2.5吋 SATAIII SSD\r\n讀545m tl...
# 4   送★WD隨身保溫瓶WD SSD 250GB M.2 SATA 3D NAND固態硬碟\r\n...
# 5   送★WD隨身保溫瓶WD 綠標 SSD 240GB M.2 2280 SATA 固態硬碟\r\...
# 6   Seagate Fast SSD 500GB 外接式固態硬碟\r\n讀540m 寫500m ...
# 7   技嘉 GIGABYTE 512GB 2.5吋 SATAIII SSD\r\n規格尺寸: 2....
# 8   Seagate Fast SSD 1TB 外接式固態硬碟\r\n讀540m 寫500m tl...
# 9   技嘉 GIGABYTE 240GB 2.5吋 SATAIII SSD\r\n規格尺寸: 2....
# 10  送★WD隨身保溫瓶WD 綠標 SSD 240GB M.2 2280 SATA 固態硬碟\r\...
# 11  送★WD隨身保溫瓶WD SSD 480GB M.2 2280 SATA 固態硬碟(綠標)\r...
# 12  技嘉 GIGABYTE 128GB M.2 2280 PCIe SSD\r\n規格尺寸: m...
# 13  送★WD隨身保溫瓶WD SSD 2TB M.2 SATA 3D NAND固態硬碟\r\n讀5...
# 14  Seagate Fast SSD 2TB 外接式固態硬碟\r\n讀540m 寫500m tl...
# 15  Seagate Fast SSD 250GB 外接式固態硬碟\r\n讀540m 寫500m ...
# 16  送★WD隨身保溫瓶WD 綠標 SSD 240GB 2.5吋固態硬碟\r\n讀545m tlc...
# 17  WD SSD 480GB 2.5吋固態硬碟(綠標)\r\n讀545m tlc 三年保\r\n...
# 18  送★WD隨身保溫瓶WD SSD 250GB 2.5吋 3D NAND 固態硬碟\r\n讀55...
# 19  WD 綠標 SSD 120GB M.2 2280 SATA 固態硬碟\r\n讀545m tl...

# %%
products_all = products_all.loc[products_all['name'].notnull(), ['name','originPrice','price','describe']]

# %%
products_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 19
# Data columns (total 4 columns):
# name           20 non-null object
# originPrice    20 non-null int64
# price          20 non-null int64
# describe       20 non-null object
# dtypes: int64(2), object(2)
# memory usage: 800.0+ bytes
